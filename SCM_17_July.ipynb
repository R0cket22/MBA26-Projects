# %%
# step function

import numpy as np
import matplotlib.pyplot as plt

def step_function (x):
    return np.where (x>= 0, 1, 0)

x= np.linspace (-10, 10, 100)
y= step_function (x)

plt.plot(x,y)
plt.title("Step Function")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
# sigmoid function

import numpy as np
import matplotlib.pyplot as plt

def sigmoid (x):
    return 1/(1+np.exp(-x))


x= np.linspace (-10, 10, 100)
y= sigmoid(x)

plt.plot(x,y)
plt.title("Sigmoid Function")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def tanh(x):
    return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

x = np.linspace(-10, 10, 100)
y = tanh(x)

plt.plot(x, y)
plt.title("Hyperbolic Tangent")*
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
# ReLu

import numpy as np
import matplotlib.pyplot as plt

def relu (x):
    return np.maximum (0,x)

x= np.linspace (-10, 10, 100)
y= relu (x)

plt.plot(x,y)
plt.title("ReLu")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
# Leaky ReLu

import numpy as np
import matplotlib.pyplot as plt

def leaky_relu (x, alpha = 0.07):
    return np.where (x > 0, x, alpha * x )

x= np.linspace (-10, 10, 100)
y_leaky_relu = leaky_relu (x, aplha = 0.07)

plt.figure()
plt.plot(x, y_leaky_relu, label = 'Leaky ReLu', color = 'red')

plt.title ("Leaky ReLU")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 10
#       7     return np.where (x > 0, x, alpha * x )
#       9 x= np.linspace (-10, 10, 100)
# ---> 10 y_leaky_relu = leaky_relu (x, aplha = 0.07)
#      12 plt.figure()
#      13 plt.plot(x, y_leaky_relu, label = 'Leaky ReLu', color = 'red')
#
# TypeError: leaky_relu() got an unexpected keyword argument 'aplha'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define ReLU
def relu(x):
    return np.maximum(0, x)

# Define Leaky ReLU
def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

# Generate input data
x = np.linspace(-10, 10, 100)
y_relu = relu(x)
y_leaky_relu = leaky_relu(x)

# Plot both functions
plt.plot(x, y_relu, label="ReLU", linewidth=2)
plt.plot(x, y_leaky_relu, label="Leaky ReLU (α=0.01)", linestyle='--', linewidth=2)

# Graph details
plt.title("ReLU vs Leaky ReLU")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()
