# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Download resources (do this once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Load your Excel review data
file_path = "C:/Users/singh/Downloads/text_analytics.xlsx"
df = pd.read_excel(file_path, sheet_name='review')

df.info()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review ID    50 non-null     int64
#  1   Review Text  50 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 932.0+ bytes

# %%
# Step 1: Lowercase
df['Lowercase'] = df['Review Text'].str.lower()
df
# Out:
#     Review ID                                        Review Text  \
# 0           1  The phone's battery life is amazing, but the c...
# 1           2  Excellent performance, but the screen resoluti...
# 2           3  Comfortable to use, but the sound quality coul...
# 3           4  Picture quality is great, but the remote is ve...
# 4           5  Terrible customer service; not buying this again.
# 5           6  Fast, reliable, and smooth operation. Highly r...
# 6           7  The build quality is mediocre. Not worth the p...
# 7           8      Very user-friendly with an excellent display.
# 8           9  Horrible battery life; keeps dying after a few...
# 9          10  Keyboard is comfortable, but the trackpad is u...
# 10         11  Poor noise cancellation. Too much external noi...
# 11         12  Great value for money; would definitely recomm...
# 12         13               Works as expected; no issues so far.
# ...

# %%
import nltk
nltk.download('punkt', force=True)  # Only 'punkt', NOT 'punkt_tab'
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\singh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# !pip install --upgrade nltk

# %%
import nltk
nltk.download('punkt', force=True)
from nltk.tokenize import word_tokenize
print(word_tokenize("Hello, world! How are you today?"))
